# %% [markdown]
# # Taxonomy
#
# The purpose of this notebook is to join the table `train.csv` with a taxonomy table.

# %%
import pandas as pd
taxonomy = pd.read_csv("species.csv")
taxonomy.shape
# Out:
# (26, 8)

# %%
#taxonomy.sort_values(by = ['infraorder','family','genus','specy']).drop(columns = ['wikipedia','image','size']).set_index('specy_id')
taxonomy = taxonomy.sort_values(by = ['specy']).drop(columns = ['wikipedia','image','size']).set_index('specy_id')

# %%
taxonomy
# Out:
#                           infraorder           family            genus  \
# specy_id
# minke_whale                  Cetacea  Balaenopteridae     Balaenoptera
# sei_whale                    Cetacea  Balaenopteridae     Balaenoptera
# brydes_whale                 Cetacea  Balaenopteridae     Balaenoptera
# blue_whale                   Cetacea  Balaenopteridae     Balaenoptera
# fin_whale                    Cetacea  Balaenopteridae     Balaenoptera
# commersons_dolphin           Cetacea      Delphinidae  Cephalorhynchus
# common_dolphin               Cetacea      Delphinidae        Delphinus
# beluga                       Cetacea     Monodontidae   Delphinapterus
# southern_right_whale         Cetacea       Balaenidae        Eubalaena
# gray_whale                   Cetacea  Balaenopteridae     Eschrichtius
# pygmy_killer_whale           Cetacea      Delphinidae           Feresa
# short_finned_pilot_whale     Cetacea      Delphinidae     Globicephala
# pilot_whale                  Cetacea      Delphinidae     Globicephala
# white_sided_dolphin          Cetacea      Delphinidae   Lagenorhynchus
# frasiers_dolphin             Cetacea      Delphinidae    Lagenodelphis
# dusky_dolphin                Cetacea      Delphinidae   Lagenorhynchus
# humpback_whale               Cetacea  Balaenopteridae        Megaptera
# killer_whale                 Cetacea      Delphinidae          Orcinus
# false_killer_whale           Cetacea      Delphinidae        Pseudorca
# melon_headed_whale           Cetacea      Delphinidae    Peponocephala
# pantropic_spotted_dolphin    Cetacea      Delphinidae         Stenella
# rough_toothed_dolphin        Cetacea      Delphinidae            Steno
# spotted_dolphin              Cetacea      Delphinidae         Stenella
# spinner_dolphin              Cetacea      Delphinidae         Stenella
# bottlenose_dolphin           Cetacea      Delphinidae         tursiops
# cuviers_beaked_whale         Cetacea        Ziphiidae          Ziphius
#
#                                       specy
# specy_id
# minke_whale                B. acutorostrata
# sei_whale                       B. borealis
# brydes_whale                      B. brydei
# blue_whale                      B. musculus
# fin_whale                       B. physalus
# commersons_dolphin           C. commersonii
# common_dolphin                   D. delphis
# beluga                            D. leucas
# southern_right_whale           E. australis
# gray_whale                      E. robustus
# pygmy_killer_whale             F. attenuata
# short_finned_pilot_whale   G. macrorhynchus
# pilot_whale                        G. melas
# white_sided_dolphin               L. acutus
# frasiers_dolphin                   L. hosei
# dusky_dolphin                   L. obscurus
# humpback_whale              M. novaeangliae
# killer_whale                        O. orca
# false_killer_whale            P. crassidens
# melon_headed_whale               P. electra
# pantropic_spotted_dolphin      S. attenuata
# rough_toothed_dolphin        S. bredanensis
# spotted_dolphin                S. frontalis
# spinner_dolphin             S. longirostris
# bottlenose_dolphin             T. truncatus
# cuviers_beaked_whale         Z. cavirostris

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   specy_id    26 non-null     object
#  1   infraorder  26 non-null     object
#  2   family      26 non-null     object
#  3   genus       26 non-null     object
#  4   specy       26 non-null     object
#  5   wikipedia   26 non-null     object
#  6   image       26 non-null     object
#  7   size        24 non-null     object
# dtypes: object(8)
# memory usage: 1.8+ KB

# %%
df.head(5)
# Out:
#              specy_id infraorder           family           genus  \
# 0  bottlenose_dolphin    Cetacea      Delphinidae        tursiops
# 1              beluga    Cetacea     Monodontidae  Delphinapterus
# 2      humpback_whale    Cetacea  Balaenopteridae       Megaptera
# 3          blue_whale    Cetacea  Balaenopteridae    Balaenoptera
# 4  false_killer_whale    Cetacea      Delphinidae       Pseudorca
#
#              specy                                         wikipedia  \
# 0     T. truncatus  https://en.wikipedia.org/wiki/Bottlenose_dolphin
# 1        D. leucas        https://en.wikipedia.org/wiki/Beluga_whale
# 2  M. novaeangliae      https://en.wikipedia.org/wiki/Humpback_whale
# 3      B. musculus          https://en.wikipedia.org/wiki/Blue_whale
# 4    P. crassidens  https://en.wikipedia.org/wiki/False_killer_whale
#
#                                                image  \
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...
#
#                                                 size
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...

# %%
df.describe()
# Out:
#                   specy_id infraorder       family         genus  \
# count                   26         26           26            26
# unique                  26          1            5            18
# top     bottlenose_dolphin    Cetacea  Delphinidae  Balaenoptera
# freq                     1         26           16             5
#
#                specy                                         wikipedia  \
# count             26                                                26
# unique            26                                                26
# top     T. truncatus  https://en.wikipedia.org/wiki/Bottlenose_dolphin
# freq               1                                                 1
#
#                                                     image  \
# count                                                  26
# unique                                                 26
# top     https://upload.wikimedia.org/wikipedia/commons...
# freq                                                    1
#
#                                                      size
# count                                                  24
# unique                                                 23
# top     https://upload.wikimedia.org/wikipedia/commons...
# freq                                                    2

# %%
df.shape
# Out:
# (26, 8)

# %%
print(df.isnull().sum())
# Out:
# specy_id      0
# infraorder    0
# family        0
# genus         0
# specy         0
# wikipedia     0
# image         0
# size          2
# dtype: int64

# %%
# To know how data are related to each other
df.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
